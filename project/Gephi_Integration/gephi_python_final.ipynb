# %% [markdown]
# # extract data from Web URL

# %%
import os
from langchain_core.documents import Document 
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
# List of URLs
urls = [
    'https://en.wikipedia.org/wiki/Dana_White',
    'https://en.wikipedia.org/wiki/Elon_Musk',
    'https://en.wikipedia.org/wiki/Mark_Zuckerberg',
    'https://en.wikipedia.org/wiki/Bill_Gates',
    'https://en.wikipedia.org/wiki/Jeff_Bezos',
    'https://en.wikipedia.org/wiki/Steve_Jobs',
    'https://en.wikipedia.org/wiki/Sam_Altman',
    # 'https://en.wikipedia.org/wiki/Mukesh_Ambani',
    # 'https://en.wikipedia.org/wiki/Jensen_Huang',
    # 'https://en.wikipedia.org/wiki/Satoshi_Nakamoto',
    # 'https://en.wikipedia.org/wiki/Donald_Trump',
    'https://en.wikipedia.org/wiki/Larry_Ellison',
    'https://en.wikipedia.org/wiki/Larry_Page',
    'https://en.wikipedia.org/wiki/Mark_Cuban',
    #'https://en.wikipedia.org/wiki/Ratan_Tata',
    #'https://en.wikipedia.org/wiki/Brian_Chesky',
    #'https://en.wikipedia.org/wiki/Jack_Dorsey',
    'https://en.wikipedia.org/wiki/Satya_Nadella'
]

# Initialize an empty list
url_list = []

# Loop through the URLs and add them to the list
for url in urls:
    url_list.append(url)

# Display the list
print(url_list)
# Out:
# ['https://en.wikipedia.org/wiki/Dana_White', 'https://en.wikipedia.org/wiki/Elon_Musk', 'https://en.wikipedia.org/wiki/Mark_Zuckerberg', 'https://en.wikipedia.org/wiki/Bill_Gates', 'https://en.wikipedia.org/wiki/Jeff_Bezos', 'https://en.wikipedia.org/wiki/Steve_Jobs', 'https://en.wikipedia.org/wiki/Sam_Altman', 'https://en.wikipedia.org/wiki/Larry_Ellison', 'https://en.wikipedia.org/wiki/Larry_Page', 'https://en.wikipedia.org/wiki/Mark_Cuban', 'https://en.wikipedia.org/wiki/Satya_Nadella']

# %%
import re

def clean_text(text):
    # Remove HTML tags
    text = re.sub(r'<[^>]*?>', '', text)
    # Remove URLs
    text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)
    # Remove special characters
    text = re.sub(r'[^a-zA-Z0-9 ]', '', text)
    # Replace multiple spaces with a single space
    text = re.sub(r'\s{2,}', ' ', text)
    # Trim leading and trailing whitespace
    text = text.strip()
    # Remove extra whitespace
    text = ' '.join(text.split())
    return text

# %%
# extract the data from the URLs 
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_community.document_loaders import WebBaseLoader

def extract_data_from_URL(url):
    loader=WebBaseLoader([url])
    data=loader.load().pop().page_content
    data=clean_text(data)
    documents=[Document(page_content=data)]
    # print(documents)
    splitter=RecursiveCharacterTextSplitter(chunk_size=3000,chunk_overlap=100)
    smaller_doc=splitter.split_documents(documents)
    print(len(smaller_doc))
    return smaller_doc

# %% [markdown]
# # GROQ API

# %%
import os 
from groq import Groq 
from openai import AzureOpenAI

client=Groq(api_key=os.getenv('GROQ_API_KEY'))
# client=AzureOpenAI(
#         api_key=os.getenv('AZURE_OPENAI_API_KEY'),
#         azure_endpoint=os.getenv('AZURE_OpenAI_ENDPOINT'),
#         api_version=os.getenv('AZURE_OpenAI_API_VERSION')
#     )

# %%
# create system prompt to extract data in JSON format as required

system=""" You are a network graph maker tasked with analyzing the relationships involving top entrepreneurs. Your job is to process the provided context chunk (delimited by ```) and extract an ontology of terms that represent key entrepreneurs, their associated entities, and all kinds of relationships present in the context.

**Guidelines for Extraction:**

1. **Identify Key Entrepreneurs and Related Terms**:
   - Extract key entrepreneurs and related concepts such as:
     - Companies, organizations, or industries they are associated with.
     - Collaborators, partners, rivals, or competitors.
     - Key innovations, achievements, or milestones.
     - Locations, events, or time periods relevant to their actions.

2. **Identify Relationships**:
   - Extract all types of relationships between entrepreneurs and other entities (or between entities themselves).
   - Relationships can include:
     - Professional roles or associations.
     - Business partnerships, collaborations, or rivalries.
     - Innovations or contributions to industries.
     - Personal connections or influences.
     - Historical events or shared milestones.

3. **Define Relationships**:
   - Clearly specify the nature of each relationship in simple and concise terms.
   - Relationships should convey meaningful connections relevant to the context.

**Response Format**:
- Provide your output **strictly as a list of JSON objects**. No additional text, descriptions, or comments are allowed.
- Each object should include the following fields:
  - `"node_1"`: The first entity in the relationship (can be a person, organization, or concept).
  - `"node_2"`: The second entity in the relationship.
  - `"edge"`: A concise sentence describing the relationship between `node_1` and `node_2`.

**Example Output**:
[
   {
       "node_1": "Elon Musk",
       "node_2": "SpaceX",
       "edge": "Elon Musk founded SpaceX to revolutionize space exploration."
   },
   {
       "node_1": "Steve Jobs",
       "node_2": "Apple Inc.",
       "edge": "Steve Jobs co-founded Apple Inc., a leading tech company."
   },
   {
       "node_1": "Mark Zuckerberg",
       "node_2": "Sheryl Sandberg",
       "edge": "Sheryl Sandberg worked closely with Mark Zuckerberg as COO of Facebook."
   },
   {
       "node_1": "Jeff Bezos",
       "node_2": "Blue Origin",
       "edge": "Jeff Bezos founded Blue Origin to focus on space exploration."
   }
]

**Important Note**:
- Always respond exclusively in JSON format. Any deviation from the JSON structure or inclusion of additional text will not be accepted.

Please provide the context containing information about entrepreneurs and their relationships for analysis.

"""

# %%
import requests
import time
from itertools import cycle
results=[]
models = [
    'llama-3.1-8b-instant',
    'llama3-groq-8b-8192-tool-use-preview',
    'llama3-8b-8192',
    'llama-3.2-1b-preview'
]
model_cycle = cycle(models)  # Create an infinite cycle of models
model_name = next(model_cycle)  # Start with the first model
for url in urls:
    
    try:
        smaller_doc=extract_data_from_URL(url)
        for doc in smaller_doc[:50]:
            chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "system",
                    "content": system
                },
                {
                    "role": "user",
                    "content": doc.page_content,
                }
            ],
            model=model_name,
            #model='gpt-4'
            )
            results.append(chat_completion.choices[0].message.content)
    except Exception as e:
        print('Exception',e)
        errordata=e.args[0]
        
        if 'rate_limit_exceeded' in errordata:
            print('Rate limit exceeded for model:', model_name)
            model_name = next(model_cycle)  # Switch to the next model
            print('Switching to model:', model_name)
            
    
len(results)
# Out:
# 11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 16
#      13 for url in urls:
#      15     try:
# ---> 16         smaller_doc=extract_data_from_URL(url)
#      17         for doc in smaller_doc[:50]:
#      18             chat_completion = client.chat.completions.create(
#      19             messages=[
#      20                 {
#    (...)
#      30             #model='gpt-4'
#      31             )
#
# Cell In[4], line 8, in extract_data_from_URL(url)
#       6 def extract_data_from_URL(url):
#       7     loader=WebBaseLoader([url])
# ----> 8     data=loader.load().pop().page_content
#       9     data=clean_text(data)
#      10     documents=[Document(page_content=data)]
#
# File d:\anaconda\envs\genai\lib\site-packages\langchain_core\document_loaders\base.py:31, in BaseLoader.load(self)
#      29 def load(self) -> list[Document]:
#      30     """Load data into Document objects."""
# ---> 31     return list(self.lazy_load())
#
# File d:\anaconda\envs\genai\lib\site-packages\langchain_community\document_loaders\web_base.py:329, in WebBaseLoader.lazy_load(self)
#     327 """Lazy load text from the url(s) in web_path."""
#     328 for path in self.web_paths:
# --> 329     soup = self._scrape(path, bs_kwargs=self.bs_kwargs)
#     330     text = soup.get_text(**self.bs_get_text_kwargs)
#     331     metadata = _build_metadata(soup, path)
#
# File d:\anaconda\envs\genai\lib\site-packages\langchain_community\document_loaders\web_base.py:316, in WebBaseLoader._scrape(self, url, parser, bs_kwargs)
#     314 elif self.autoset_encoding:
#     315     html_doc.encoding = html_doc.apparent_encoding
# --> 316 return BeautifulSoup(html_doc.text, parser, **(bs_kwargs or {}))
#
# File d:\anaconda\envs\genai\lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File d:\anaconda\envs\genai\lib\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File d:\anaconda\envs\genai\lib\site-packages\bs4\builder\_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381     parser.close()
#     382 except AssertionError as e:
#     383     # html.parser raises AssertionError in rare cases to
#     384     # indicate a fatal problem with the markup, especially
#     385     # when there's an error in the doctype declaration.
#
# File d:\anaconda\envs\genai\lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File d:\anaconda\envs\genai\lib\html\parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File d:\anaconda\envs\genai\lib\html\parser.py:344, in HTMLParser.parse_starttag(self, i)
#     342     self.handle_startendtag(tag, attrs)
#     343 else:
# --> 344     self.handle_starttag(tag, attrs)
#     345     if tag in self.CDATA_CONTENT_ELEMENTS:
#     346         self.set_cdata_mode(tag)
#
# File d:\anaconda\envs\genai\lib\site-packages\bs4\builder\_htmlparser.py:137, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     135 #print("START", name)
#     136 sourceline, sourcepos = self.getpos()
# --> 137 tag = self.soup.handle_starttag(
#     138     name, None, None, attr_dict, sourceline=sourceline,
#     139     sourcepos=sourcepos
#     140 )
#     141 if tag and tag.is_empty_element and handle_empty_element:
#     142     # Unlike other parsers, html.parser doesn't send separate end tag
#     143     # events for empty-element tags. (It's handled in
#    (...)
#     149     # don't want handle_endtag() to cross off any previous end
#     150     # events for tags of this name.
#     151     self.handle_endtag(name, check_already_closed=False)
#
# File d:\anaconda\envs\genai\lib\site-packages\bs4\__init__.py:749, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     744 if (self.parse_only and len(self.tagStack) <= 1
#     745     and (self.parse_only.text
#     746          or not self.parse_only.search_tag(name, attrs))):
#     747     return None
# --> 749 tag = self.element_classes.get(Tag, Tag)(
#     750     self, self.builder, name, namespace, nsprefix, attrs,
#     751     self.currentTag, self._most_recent_element,
#     752     sourceline=sourceline, sourcepos=sourcepos,
#     753     namespaces=namespaces
#     754 )
#     755 if tag is None:
#     756     return tag
#
# File d:\anaconda\envs\genai\lib\site-packages\bs4\element.py:1199, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1191 class Tag(PageElement):
#    1192     """Represents an HTML or XML tag that is part of a parse tree, along
#    1193     with its attributes and contents.
#    1194
#    1195     When Beautiful Soup parses the markup <b>penguin</b>, it will
#    1196     create a Tag object representing the <b> tag.
#    1197     """
# -> 1199     def __init__(self, parser=None, builder=None, name=None, namespace=None,
#    1200                  prefix=None, attrs=None, parent=None, previous=None,
#    1201                  is_xml=None, sourceline=None, sourcepos=None,
#    1202                  can_be_empty_element=None, cdata_list_attributes=None,
#    1203                  preserve_whitespace_tags=None,
#    1204                  interesting_string_types=None,
#    1205                  namespaces=None
#    1206     ):
#    1207         """Basic constructor.
#    1208
#    1209         :param parser: A BeautifulSoup object.
#    (...)
#    1240             construct CSS selectors.
#    1241         """
#    1242         if parser is None:
#
# KeyboardInterrupt:

# %% [markdown]
# # python to Gephi using LLM

# %%
# connect to gephi server
from gephistreamer import graph
from gephistreamer import streamer
import json

# create a stream 
stream = streamer.Streamer(streamer.GephiWS(hostname="localhost", port=8080, workspace="workspace1"))

# %%
combined_json_object=[]
for res in results:
    try: 
        json_object=json.loads(res)
        # combined_json_boject.extend(json.loads(json_object))
        print(res)
        for data in json_object:
            node_a = graph.Node(data['node_1'],custom_property=1)
            node_b = graph.Node(data['node_2'],custom_property=2)
            stream.add_node(node_a,node_b)
            edge_ab = graph.Edge(node_a,node_b,custom_property=data['edge'])
            stream.add_edge(edge_ab)

    except Exception as e:
        print('buggy JSON object', e)
# Out:
# [ {
#   "node_1": "Dana White",
#   "node_2": "Ultimate Fighting Championship",
#   "edge": "Dana White is the CEO and President of the Ultimate Fighting Championship."
# }, {
#   "node_1": "Dana White",
#   "node_2": "Anne White",
#   "edge": "Anne White is Dana White's wife."
# }, {
#   "node_1": "Dana White",
#   "node_2": "Manchester, Connecticut",
#   "edge": "Dana White was born in Manchester, Connecticut, on July 28, 1969."
# }, {
#   "node_1": "Dana White",
#   "node_2": "Las Vegas",
#   "edge": "When Dana White was in third grade, his family moved to Las Vegas."
# }, {
#   "node_1": "Dana White",
#   "node_2": "Bishop Gorman High School",
#   "edge": "Dana White attended Bishop Gorman High School in Las Vegas, Nevada."
# }, {
#   "node_1": "Dana White",
#   "node_2": "Lorenzo Fertitta",
#   "edge": "Dana White first met Lorenzo Fertitta while attending Bishop Gorman High School, although they became close friends later."
# }, {
#   "node_1": "Dana White",
#   "node_2": "Levant, Maine",
#   "edge": "During his childhood, Dana White spent summers with his grandparents in Levant, Maine."
# }, {
#   "node_1": "Dana White",
#   "node_2": "Hermon High School",
#   "edge": "Dana White graduated from Hermon High School in Maine."
# }, {
#   "node_1": "Dana White",
#   "node_2": "Quincy College",
#   "edge": "Dana White started college at Quincy College but dropped out during his first semester."
# }, {
#   "node_1": "Dana White",
#   "node_2": "UMass Boston",
#   "edge": "Dana White also started college at UMass Boston but dropped out during his first semester as well."
# } ]
# [
#   {
#       "node_1": "Dana White",
#       "node_2": "Quincy College",
#       "edge": "Dana White attended Quincy College."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "UMass Boston",
#       "edge": "Dana White attended UMass Boston, but dropped out during his first semester."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "asphalt laying job",
#       "edge": "Dana White had a job laying asphalt."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Irish bar bouncer",
#       "edge": "Dana White worked as a bouncer at an Irish bar."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Boston Harbor Hotel bellhop",
#       "edge": "Dana White was a bellhop at the Boston Harbor Hotel."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Peter Welch",
#       "edge": "Dana White befriended former Golden Gloves champion Peter Welch through boxing."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "boxing gym",
#       "edge": "Dana White started a boxing gym in Boston with Peter Welch."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Whitey Bulger",
#       "edge": "Dana White said he left Boston after being threatened by mobster Whitey Bulger and his associate Kevin Weeks."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Las Vegas",
#       "edge": "Dana White returned to Las Vegas in the early 1990s."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "boxercise gyms",
#       "edge": "Dana White continued running boxercise gyms in Las Vegas."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "John Lewis",
#       "edge": "Dana White trained jiujitsu under the tutelage of John Lewis."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Lorenzo Fertitta",
#       "edge": "Dana White reconnected with Lorenzo Fertitta and his brother Frank after a mutual friends wedding."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Tito Ortiz and Chuck Liddell",
#       "edge": "Dana White met mixed martial artists Tito Ortiz and Chuck Liddell through John Lewis."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Bob Meyrowitz",
#       "edge": "Dana White met Bob Meyrowitz, the owner of Semaphore Entertainment Group, the parent company of the UFC."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Lorenzo and Frank Fertitta",
#       "edge": "Dana White contacted Lorenzo Fertitta to acquire the UFC on behalf of the Fertitta brothers."
#   },
#   {
#       "node_1": "Lorenzo Fertitta",
#       "node_2": "Dana White",
#       "edge": "Dana White helped Lorenzo and Frank Fertitta acquire the UFC for $2 million."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "UFC",
#       "edge": "Dana White was installed as the UFC's president after the acquisition."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Donald Trump",
#       "edge": "Dana White developed a long-term friendship with Donald Trump after hosting UFC events at the Trump Taj Mahal."
#   }
# ]
# [
#    {
#        "node_1": "Dana White",
#        "node_2": "Donald Trump",
#        "edge": "Dana White had a long-term friendship with Donald Trump."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Frank Fertitta",
#        "edge": "Dana White, Frank Fertitta, and Lorenzo Fertitta co-owned the UFC during its early years."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Lorenzo Fertitta",
#        "edge": "Dana White, Frank Fertitta, and Lorenzo Fertitta co-owned the UFC during its early years."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Craig Piligian",
#        "edge": "Craig Piligian helped Dana White develop the concept for 'The Ultimate Fighter'."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "The UFC",
#        "edge": "Dana White became the president of the UFC and led its growth into a highly successful business."
#    },
#    {
#        "node_1": "The UFC",
#        "node_2": "Chuck Liddell",
#        "edge": "Chuck Liddell was a key fighter for the UFC, headlining UFC 66 with Tito Ortiz."
#    },
#    {
#        "node_1": "The UFC",
#        "node_2": "Tito Ortiz",
#        "edge": "Tito Ortiz was a key fighter for the UFC, headlining UFC 66 with Chuck Liddell."
#    },
#    {
#        "node_1": "The UFC",
#        "node_2": "Zuffa",
#        "edge": "Zuffa was the parent company of the UFC during Dana White's leadership."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Ronda Rousey",
#        "edge": "Dana White oversaw the UFC's first women's bout, featuring Ronda Rousey and Liz Carmouche."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Conor McGregor",
#        "edge": "Conor McGregor became one of the UFC's top stars under Dana White's leadership."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "WMEIMG",
#        "edge": "Dana White sold his majority stake in the UFC to a group led by WMEIMG in 2016."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "ESPN",
#        "edge": "The UFC signed a deal with ESPN under Dana White's leadership in 2019."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "WWE",
#        "edge": "The UFC merged with WWE to form a new public company, TKO Group Holdings, under Dana White's leadership in 2023."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Floyd Mayweather Jr.",
#        "edge": "Dana White copromoted the Mayweather vs McGregor fight due to McGregor's affiliation with the UFC."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Callum Walsh",
#        "edge": "Dana White promoted a boxing card featuring Callum Walsh in 2024."
#    }
# ]
# buggy JSON object Expecting ',' delimiter: line 65 column 200 (char 2488)
# buggy JSON object Expecting value: line 22 column 1 (char 2802)
# [
#    {
#        "node_1": "Dana White",
#        "node_2": "Caesars Palace",
#        "edge": "Dana White claims to have lost 8 million in one night and won 26 million from January to March 2024 at Caesars Palace."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Caesars Palace",
#        "edge": "Dana White stated a goal in life of being allowed to play 1 million per hand at a casino."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Anne White",
#        "edge": "Dana White and his wife Anne got into a physical altercation at a New Years Eve party in 2022."
#    },
#    {
#        "node_1": "UFC",
#        "node_2": "California Legislative Womens Caucus",
#        "edge": "The California Legislative Womens Caucus requested Dana White's removal from his role in the UFC."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Tuptim Jadnooleum",
#        "edge": "Dana White donated 50,000 for a liver transplant to Tuptim Jadnooleum in 2010."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Tiger Muay Thai",
#        "edge": "Dana White donated to help his instructor Kru Nai Rattanachai through Tiger Muay Thai in Phuket, Thailand."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "UFC 242",
#        "edge": "Dana White donated 100,000 to the charity of Dustin Poirier after UFC 242 in 2019."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Good Fight Foundation",
#        "edge": "Dana White also donated 100,000 to Dustin Poirier's charity foundation."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Donald J. Trump rally victims",
#        "edge": "Dana White donated 50,000 to support victims affected by the attempted assassination of Donald J. Trump in 2024."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Armed Forces Foundation",
#        "edge": "Dana White was awarded the Patriot Award by the Armed Forces Foundation."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "World MMA Awards",
#        "edge": "Dana White was named Leading Man of the Year by the World MMA Awards in 2008."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Wrestling Observer Newsletter",
#        "edge": "Dana White was awarded Promoter of the Year by the Wrestling Observer Newsletter in 2005, 2015, and 2016."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Nevada Sportsman of the Year",
#        "edge": "Dana White was named Nevada Sportsman of the Year in 2009."
#    }
# ]
# [
#   {
#     "node_1": "Dana White",
#     "node_2": "UFC",
#     "edge": "Dana White helped build UFC into a successful company."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "Lorenzo Fertitta",
#     "edge": "Dana White worked closely with Lorenzo Fertitta to grow UFC."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "Boston",
#     "edge": "Dana White has roots in Boston, where he had a HS program supported by UFC bosses."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "JiuJitsu",
#     "edge": "Dana White has experience with JiuJitsu as a boxercise instructor."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "Whitey Bulger",
#     "edge": "Dana White was familiar with Whitey Bulger from Black Mass experience."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "Donald Trump",
#     "edge": "Dana White has interacted with Donald Trump, who he has endorsed for President."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "John McCain",
#     "edge": "Dana White mentioned John McCain in conversations about his father."
#   },
#   {
#     "node_1": "Ronda Rousey",
#     "node_2": "UFC",
#     "edge": "Ronda Rousey broke barriers for women in UFC and holds multiple UFC titles."
#   },
#   {
#     "node_1": "Ronda Rousey",
#     "node_2": "UFC money",
#     "edge": "Ronda Rousey used to make more money than Conor McGregor."
#   },
#   {
#     "node_1": "Jens Pulver",
#     "node_2": "UFC",
#     "edge": "Jens Pulver was the first UFC lightweight champion."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "WMEIMG",
#     "edge": "Dana White sold UFC to WMEIMG and retained control of the company."
#   },
#   {
#     "node_1": "Lance Pugmire",
#     "node_2": "Dana White",
#     "edge": "Lance Pugmire is a journalist and a former boxing writer that has interviewed Dana White."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "UFC sale",
#     "edge": "Dana White was involved in the sale of UFC to WMEIMG for 4 billion."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "Endeavor",
#     "edge": "Dana White confirmed the sale of his 10% ownership of UFC to Endeavor and WMEIMG's parent company."
#   }
# ]
# [
#    {
#        "node_1": "Dana White",
#        "node_2": "UFC",
#        "edge": "Dana White is the President of UFC, leading its resurgence."
#    },
#    {
#        "node_1": "UFC",
#        "node_2": "WMEIMG",
#        "edge": "WMEIMG sold UFC for $4 billion in 2016."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "WWE",
#        "edge": "Dana White agreed to a 7-year contract extension with UFC in 2019."
#    },
#    {
#        "node_1": "UFC",
#        "node_2": "WWE",
#        "edge": "UFC merged with WWE to create TKO Group Holdings in 2023."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Triple H",
#        "edge": "Dana White posed with Triple H after the UFC-WWE merger, signaling a new titleholder."
#    },
#    {
#        "node_1": "TKO Group Holdings",
#        "node_2": "Endeavor",
#        "edge": "TKO Group Holdings was announced as a result of the Endeavor acquisition of UFC and WWE."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Boxing",
#        "edge": "Dana White is interested in promoting boxing matches in the UFC."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Surfers",
#        "edge": "Dana White brought UFC's 'Ultimate Surfer' series to TV, though it was poorly received."
#    },
#    {
#        "node_1": "UFC",
#        "node_2": "Thrill One Sports Entertainment",
#        "edge": "UFC and WWE held shares in Thrill One Sports Entertainment before being acquired."
#    }
# ]
# [
#    {
#        "node_1": "Dana White",
#        "node_2": "UFC",
#        "edge": "Dana White is the president of the UFC."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Menieres disease",
#        "edge": "Dana White has been diagnosed with Menieres disease."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Joe Rogan",
#        "edge": "Dana White has appeared on the Joe Rogan Experience podcast."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Donald Trump",
#        "edge": "Dana White strongly supports Donald Trump and even campaigned for him."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "UFC Holiday Party",
#        "edge": "Dana White has attended the UFC Holiday Party where notable figures were present."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "The Washington Times",
#        "edge": "Dana White has spoken to The Washington Times about his loyalty to Donald Trump."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "The Guardian",
#        "edge": "Dana White and the UFC have been mentioned in articles by The Guardian."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "CNN",
#        "edge": "Dana White has given interviews to CNN talking about his views on death and the pandemic."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "SB Nation",
#        "edge": "Dana White's Menieres disease story has been reported in SB Nation."
#    },
#    {
#        "node_1": "Dana White",
#        "node_2": "Stem cell treatment",
#        "edge": "Dana White has undergone stem cell treatment for Menieres disease."
#    },
#    {
#        "node_1": "Donald Trump",
#        "node_2": "The Republican convention",
#        "edge": "Dana White has given a speech at the Republican convention on behalf of Donald Trump."
#    },
#    {
#        "node_1": "Donald Trump",
#        "node_2": "Dana White",
#        "edge": "Donald Trump has included Dana White in his task force to restart the nation's economy."
#    },
#    {
#        "node_1": "Donald Trump",
#        "node_2": "UFC",
#        "edge": "Donald Trump has mentioned the UFC in relation to his economic task force."
#    },
#    {
#        "node_1": "Joe Rogan",
#        "node_2": "Dana White",
#        "edge": "Joe Rogan has featured Dana White as a guest on his podcast."
#    },
#    {
#        "node_1": "Kevin Iole",
#        "node_2": "Dana White",
#        "edge": "Kevin Iole has reported on Dana White's Menieres disease diagnosis."
#    },
#    {
#        "node_1": "Piers Morgan",
#        "node_2": "Dana White",
#        "edge": "Piers Morgan has interviewed Dana White in a television appearance."
#    },
#    {
#        "node_1": "UFC",
#        "node_2": "Dana White",
#        "edge": "The UFC is owned and operated by Dana White."
#    }
# ]
# [
#   {
#       "node_1": "Dana White",
#       "node_2": "UFC president",
#       "edge": "Dana White serves as the president of the Ultimate Fighting Championship (UFC)."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "UFC war room",
#       "edge": "Dana White uses an insane war room to plan fights, featuring samurai swords, a sabretooth skull, and a money gun."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "New England Patriots",
#       "edge": "UFC boss Dana White is a big fan of the New England Patriots."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Caesars Palace",
#       "edge": "Dana White enjoys visiting Caesars Palace, his favorite Las Vegas casino."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Caesars",
#       "edge": "Dana White clipped Caesars for $26M/$27M on Baccarat."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Tom Brady",
#       "edge": "Dana White wanted the Raiders to acquire Tom Brady but the plan failed."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Rob Gronkowski",
#       "edge": "Dana White wanted the Raiders to acquire Rob Gronkowski but the plan failed."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Rick",
#       "edge": "Dana White learned about the 1600s Japanese Katana from Rick."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Sheryl",
#       "edge": "Dana White recalls 1m bet that ruined his holiday involving Sheryl (referring to an unmentioned female relation)."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Kabib Nurmagomedov",
#       "edge": "Dana White and Kabib Nurmagomedov each donated $100K to Dustin Poirier's charity."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Samurai swords",
#       "edge": "Dana White owns samurai swords."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "A sabretooth skull",
#       "edge": "Dana White displays a sabretooth skull in his office."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "MMA",
#       "edge": "Dana White contributes to the world of Mixed Martial Arts."
#   },
#   {
#       "node_1": "Dana White",
#       "node_2": "Charity",
#       "edge": "Dana White donates to various charities."
#   },
#   {
#       "node_1": "UFC",
#       "node_2": "New Year's Eve altercation",
#       "edge": "Dana White's involvement in a New Year's Eve altercation was a challenge."
#   },
#   {
#       "node_1": "UFC",
#       "node_2": "Las Vegas shooting victims",
#       "edge": "Dana White's UFC donated $1 million to support Las Vegas shooting victims."
#   },
#   {
#       "node_1": "UFC",
#       "node_2": "Wounded soldiers",
#       "edge": "Dana White accepted the Patriot Award for his efforts in raising funds for wounded soldiers."
#   }
# ]
# [
#   {
#     "node_1": "Dana White",
#     "node_2": "Ultimate Fighting Championship",
#     "edge": "Dana White serves as the CEO and president of the Ultimate Fighting Championship (UFC)."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "The Ultimate Fighter",
#     "edge": "Dana White has been instrumental in the creation and hosting of the reality TV show The Ultimate Fighter, a flagship property of the UFC."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "TWO Group Holdings",
#     "edge": "Dana White works for TWO Group Holdings, parent company of the Ultimate Fighting Championship (UFC)."
#   },
#   {
#     "node_1": "Marshall Zelaznik",
#     "node_2": "Ultimate Fighting Championship",
#     "edge": "Marshall Zelaznik previously served as the executive vice president and COO of the Ultimate Fighting Championship."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "Wrestling Observer Newsletter",
#     "edge": "Dana White has won an award from the Wrestling Observer Newsletter, in the category of Sportsman of the Year, with a bonus $250k awarded to The Caring Place."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "Las Vegas",
#     "edge": "Dana White hails from Manchester, Connecticut but is now based in Nevada, specifically Las Vegas."
#   },
#   {
#     "node_1": "Dana White",
#     "node_2": "Mnire's disease",
#     "edge": "Dana White has been public about his struggles with Munire's disease."
#   }
# ]
# [
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Pretoria",
#         "edge": "Elon Musk was born in Pretoria, South Africa."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "South Africa",
#         "edge": "Elon Musk holds citizenship in South Africa, Canada, and the United States."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Zip2",
#         "edge": "Elon Musk co-founded Zip2, which was later acquired by Compaq."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "X.com",
#         "edge": "Elon Musk co-founded X.com, which later became PayPal."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "SpaceX",
#         "edge": "Elon Musk founded SpaceX to revolutionize space exploration."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Starlink",
#         "edge": "Elon Musk founded Starlink, a satellite internet constellation service."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Tesla",
#         "edge": "Elon Musk co-founded Tesla, a leading electric vehicle manufacturer."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "SolarCity",
#         "edge": "Elon Musk co-founded SolarCity, which was later acquired by Tesla."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Neuralink",
#         "edge": "Elon Musk founded Neuralink, a neurotechnology company."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "The Boring Company",
#         "edge": "Elon Musk founded The Boring Company, a tunnel construction firm."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Twitter X",
#         "edge": "Elon Musk acquired Twitter X, a social media platform."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Vivek Ramaswamy",
#         "edge": "Elon Musk serves as the Co-Chair of the Department of Government Efficiency alongside Vivek Ramaswamy, under the presidency of Donald Trump."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Donald Trump",
#         "edge": "Elon Musk serves as the Co-Chair under the presidency of Donald Trump, alongside Vivek Ramaswamy."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Mark Zuckerberg",
#         "edge": "Elon Musk likely sees Mark Zuckerberg as a competitor in the tech industry."
#     },
#     {
#         "node_1": "Jeff Bezos",
#         "node_2": "Blue Origin",
#         "edge": "Jeff Bezos founded Blue Origin to focus on space exploration."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Facebook",
#         "edge": "Elon Musk likely sees Facebook, led by Mark Zuckerberg, as a competitor in the tech industry."
#     }
# ]
# [
#   {
#     "node_1": "Elon Musk",
#     "node_2": "SpaceX",
#     "edge": "Elon Musk founded SpaceX to revolutionize space exploration."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Elon Musk Family",
#     "edge": "Elon Musk comes from a wealthy South African family."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "University of Pennsylvania",
#     "edge": "Elon Musk received bachelors degrees in economics and physics from the University of Pennsylvania."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "California",
#     "edge": "Elon Musk moved to California in 1995 to attend Stanford University."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Zip2",
#     "edge": "Elon Musk cofounded the online city guide software company Zip2 with his brother Kimbal."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Confinity",
#     "edge": "Elon Musk cofounded Xcom, which merged with Confinity in 2000 to form PayPal."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "PayPal",
#     "edge": "Elon Musk cofounded PayPal, which was acquired by eBay for $15 billion in 2002."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Tesla Inc.",
#     "edge": "Elon Musk was an early investor in Tesla Motors Inc, now Tesla Inc."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "X Corp",
#     "edge": "Elon Musk founded X Corp, the company that operates the social media platform X formerly Twitter."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Neuralink",
#     "edge": "Elon Musk founded Neuralink, a neurotechnology company."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "OpenAI",
#     "edge": "Elon Musk was involved in the founding of OpenAI, an AI research laboratory."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "The Boring Company",
#     "edge": "Elon Musk founded The Boring Company, a infrastructure and tunnel construction company."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "University of Pretoria",
#     "edge": "Elon Musk briefly attended the University of Pretoria before immigrating to Canada."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Canada",
#     "edge": "Elon Musk acquired Canadian citizenship through his Canadian-born mother."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "South Africa",
#     "edge": "Elon Musk was born in Pretoria, South Africa."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Queens University at Kingston",
#     "edge": "Elon Musk matriculated at Queens University at Kingston in Canada."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "University of South Africa",
#     "edge": "There is no direct association found for this node, no claim was made for this education."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "XAI",
#     "edge": "Elon Musk is involved with xAI, an AI research laboratory."
#   }
# ]
# [
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Tesla Motors Inc",
#         "edge": "Elon Musk was an early investor in Tesla Motors Inc and provided most of the initial financing."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Tesla Inc",
#         "edge": "Elon Musk led the company out of financial distress after being renamed as Tesla Inc."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "SolarCity",
#         "edge": "Elon Musk helped create SolarCity, a solar energy company that was later acquired by Tesla."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Tesla Energy",
#         "edge": "SolarCity was rebranded as Tesla Energy after its acquisition."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "The Boring Company",
#         "edge": "Elon Musk founded the tunnel construction company, The Boring Company."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Neuralink",
#         "edge": "Elon Musk cofounded Neuralink, a neurotechnology company developing brain-computer interfaces."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "OpenAI",
#         "edge": "Elon Musk was an early co-founder of OpenAI, a nonprofit artificial intelligence research company."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Xi Corp",
#         "edge": "Elon Musk merged Twitter into Xi Corp, a newly created entity."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "xai",
#         "edge": "Elon Musk founded xai, an artificial intelligence company."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "SpaceX",
#         "edge": "Although not explicitly mentioned Elon musk leads private space agency SpaceX."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "US Securities and Exchange Commission (SEC)",
#         "edge": "The SEC sued Elon Musk over claims that he had falsely announced a private takeover of Tesla."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Twitter",
#         "edge": "Elon Musk acquired Twitter for $44 billion."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Donald Trump",
#         "edge": "Elon Musk became a vocal and financial supporter of Donald Trump in early 2024."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Family of Elon Musk",
#         "edge": "Elon Musk is part of a large family with multiple siblings and half-siblings."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Kimbal Musk",
#         "edge": "Elon Musk has a younger brother named Kimbal."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Maye Musk",
#         "edge": "Elon Musk is the child of Maye Musk and Errol Musk."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Errol Musk",
#         "edge": "Elon Musk is the child of Maye Musk and Errol Musk."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Vivek Ramaswamy",
#         "edge": "Elon Musk along with Vivek Ramaswamy will co-lead Donald Trump's planned Department of Government Efficiency advisory board."
#     }
# ]
# [
#    {
#        "node_1": "Errol Musk",
#        "node_2": "Zambian emerald mine",
#        "edge": "Errol Musk was a part-owner of a Zambian emerald mine."
#    },
#    {
#        "node_1": "Errol Musk",
#        "node_2": "Pretoria City Council",
#        "edge": "Errol Musk was elected to the Pretoria City Council as a representative of the antiapartheid Progressive Party."
#    },
#    {
#        "node_1": "Errol Musk",
#        "node_2": "Progressive Party",
#        "edge": "Errol Musk represented the antiapartheid Progressive Party in the Pretoria City Council."
#    },
#    {
#        "node_1": "Errol Musk",
#        "node_2": "Elon Musk",
#        "edge": "Errol Musk is Elon Musk's father."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Joshua N Haldeman",
#        "edge": "Joshua N Haldeman was Elon Musk's maternal grandfather."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Bryanston High School",
#        "edge": "Elon Musk attended Bryanston High School."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Bryanston High School pupil",
#        "edge": "Elon Musk had an altercation with a fellow pupil at Bryanston High School."
#    },
#    {
#        "node_1": "Bryanston High School pupil",
#        "node_2": "Elon Musk",
#        "edge": "Elon Musk was bullied by the Bryanston High School pupil and his friends."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Private school",
#        "edge": "Elon Musk was enrolled in a private school after his altercation at Bryanston High School."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Waterkloof House Preparatory School",
#        "edge": "Elon Musk attended Waterkloof House Preparatory School."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Pretoria Boys High School",
#        "edge": "Elon Musk attended Pretoria Boys High School."
#    },
#    {
#        "node_1": "Errol Musk",
#        "node_2": "Elon Musk",
#        "edge": "Errol Musk denied berating Elon Musk after his altercation at Bryanston High School."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Parents",
#        "edge": "Elon Musk's parents divorced in 1980."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "University of Pretoria",
#        "edge": "Elon Musk attended the University of Pretoria for five months."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Canadian passport",
#        "edge": "Elon Musk applied for a Canadian passport to avoid South Africa's mandatory military service."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "University of Pennsylvania",
#        "edge": "Elon Musk transferred to the University of Pennsylvania two years after entering Queens University."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Queens University",
#        "edge": "Elon Musk entered Queens University in 1990."
#    }
# ]
# [
#    {
#        "node_1": "Elon Musk",
#        "node_2": "University of Kingston",
#        "edge": "Elon Musk initially attended the University of Kingston."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "University of Pennsylvania",
#        "edge": "Elon Musk transferred to the University of Pennsylvania in his final year of study."
#    },
#    {
#        "node_1": "University of Pennsylvania",
#        "node_2": "Wharton School",
#        "edge": "Elon Musk earned his Bachelor of Science in economics from the Wharton School at the University of Pennsylvania."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Pinnacle Research Institute",
#        "edge": "Elon Musk had an internship at energy storage startup Pinnacle Research Institute in Silicon Valley."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Rocket Science Games",
#        "edge": "Elon Musk had another internship at Palo Alto-based startup Rocket Science Games in Silicon Valley."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Stanford University",
#        "edge": "Elon Musk was accepted to a graduate program in materials science at Stanford University, but did not enroll."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Netscape",
#        "edge": "Elon Musk applied for a job at Netscape, but reportedly never received a response."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Zip2",
#        "edge": "Elon Musk co-founded Zip2 with his brother Kimbal and Greg Kouri to develop an Internet city guide."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Global Link Information Network",
#        "edge": "Elon Musk initially founded Global Link Information Network, later renamed Zip2."
#    },
#    {
#        "node_1": "Zip2",
#        "node_2": "The New York Times",
#        "edge": "Zip2 obtained a contract with The New York Times."
#    },
#    {
#        "node_1": "Zip2",
#        "node_2": "Chicago Tribune",
#        "edge": "Zip2 also obtained a contract with the Chicago Tribune."
#    },
#    {
#        "node_1": "Zip2",
#        "node_2": "Compaq",
#        "edge": "Compaq acquired Zip2 for $307 million in cash."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Xcom",
#        "edge": "Elon Musk cofounded Xcom with $12 million from the Compaq acquisition."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "PayPal",
#        "edge": "Elon Musk was involved with an online financial services company, which evolved into PayPal."
#    }
# ]
# [
#    {
#        "node_1": "Elon Musk",
#        "node_2": "X.com",
#        "edge": "Elon Musk founded X.com, an online bank."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Bill Harris",
#        "edge": "Bill Harris replaced Elon Musk as CEO of X.com after investors considered him inexperienced."
#    },
#    {
#        "node_1": "X.com",
#        "node_2": "Confinity",
#        "edge": "X.com merged with Confinity to avoid competition."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Peter Thiel",
#        "edge": "Peter Thiel resigned from Confinity due to a rift caused by Elon Musks preference for Microsoft over Unix-based software."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Peter Thiel",
#        "edge": "The board ousted Elon Musk and replaced him with Peter Thiel as CEO of the merged company."
#    },
#    {
#        "node_1": "Peter Thiel",
#        "node_2": "PayPal",
#        "edge": "Under Peter Thiel, the company focused on the money transfer service and was renamed PayPal."
#    },
#    {
#        "node_1": "eBay",
#        "node_2": "PayPal",
#        "edge": "eBay acquired PayPal for $1.5 billion in stock."
#    },
#    {
#        "node_1": "eBay",
#        "node_2": "Elon Musk",
#        "edge": "Elon Musk received $176 million from the acquisition of PayPal."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "X.com",
#        "edge": "Elon Musk purchased the X.com domain from PayPal for sentimental value."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "SpaceX",
#        "edge": "Elon Musk founded SpaceX in 2002 with $100 million of his own money."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Mars Society",
#        "edge": "Elon Musk became involved with the Mars Society to discuss funding plans for a growth chamber on Mars."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "NASA Administrator Charles Bolden",
#        "edge": "NASA Administrator Charles Bolden congratulated Elon Musk on the SpaceX Dragon mission."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Jim Cantrell, Adeo Ressi, and Michael D. Griffin",
#        "edge": "Elon Musk traveled to Moscow with Jim Cantrell, Adeo Ressi, and future NASA Administrator Michael D. Griffin to buy refurbished ICBMs."
#    },
#    {
#        "node_1": "SpaceX",
#        "node_2": "NASA",
#        "edge": "SpaceX was awarded a Commercial Orbital Transportation Services program contract from NASA."
#    },
#    {
#        "node_1": "SpaceX",
#        "node_2": "ELon Musk",
#        "edge": "SpaceX nearly went bankrupt after two failed rocket launches under Elon Musks leadership."
#    },
#    {
#        "node_1": "SpaceX",
#        "node_2": "ELon Musk",
#        "edge": "SpaceX finally succeeded in launching the Falcon 1 into orbit under Elon Musks leadership."
#    }
# ]
# [
#    {
#        "node_1": "Elon Musk",
#        "node_2": "SpaceX",
#        "edge": "Elon Musk founded SpaceX to pursue ambitious space projects."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Falcon 1",
#        "edge": "SpaceX successfully launched the Falcon 1 into orbit in 2008."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "SpaceX",
#        "edge": "SpaceX received a $16 billion Commercial Resupply Services contract from NASA in 2009."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "SpaceX",
#        "edge": "SpaceX achieved the first commercial spacecraft to dock with the ISS in 2012."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "SpaceX",
#        "edge": "SpaceX successfully landed the first stage of a Falcon 9 on a land platform in 2015."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "SpaceX",
#        "edge": "SpaceX successfully launched the Falcon Heavy in 2018 with Musks personal Tesla Roadster as a payload."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Starlink",
#        "edge": "SpaceX developed the Starlink constellation of low-Earth orbit satellites starting in 2015."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Starlink",
#        "edge": "SpaceX launched the first 60 operational Starlink satellites in May 2019."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "United States Department of Defense",
#        "edge": "SpaceX donated Starlink terminals to Ukraine with assistance from the US Department of Defense in 2022."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "SpaceX",
#        "edge": "SpaceX offered free data transfer subscriptions to Ukraine for a year, incurring a yearly cost of $400 million."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Ukraine",
#        "edge": "SpaceX continued to provide Starlink to Ukraine for free despite requests by the US to charge."
#    },
#    {
#        "node_1": "SpaceX",
#        "node_2": "Falcon 9",
#        "edge": "Falcon 9 became a integral part of Starlink operations with its reusability feature benefiting the mission."
#    },
#    {
#        "node_1": "SpaceX",
#        "node_2": "Dragon",
#        "edge": "The Dragon spacecraft played a pivotal role with the Falcon 9 rocket in providing ISS resupply services for NASA."
#    },
#    {
#        "node_1": "SpaceX",
#        "node_2": "International Space Station (ISS)",
#        "edge": "The Falcon 9 rocket and Dragon spacecraft successfully released payloads to the ISS as part of a $16 billion NASA contract."
#    },
#    {
#        "node_1": "SpaceX",
#        "node_2": "NASA",
#        "edge": "SpaceX earned the $16 billion Commercial Resupply Services contract with NASA in 2009."
#    },
#    {
#        "node_1": "SpaceX",
#        "node_2": "Russia",
#        "edge": "SpaceXs Starlink was utilized in Ukraine, but CEO Elon Musk refused to block Russian state media citing free speech concerns."
#    }
# ]
# [
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Starlink",
#        "edge": "Elon Musk refused to block Russian state media on Starlink, declaring himself a free speech absolutist."
#    },
#    {
#        "node_1": "Maria Kovtun",
#        "node_2": "Elon Musk",
#        "edge": "Someone asked Elon Musk for a comment on Russia threatening to boycott Ukraine using Tesla and Starlink, no comment. Yet."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Ukraine",
#        "edge": "Ukraine asked Elon Musk for the activation of Starlink satellites over Crimea but he denied the request due to nuclear concerns."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Tesla Motors",
#        "edge": "Elon Musk led the Series A round of investment in Tesla Motors in February 2004 and became the majority shareholder."
#    },
#    {
#        "node_1": "Martin Eberhard",
#        "node_2": "Marc Tarpenning",
#        "edge": "Martin Eberhard and Marc Tarpenning developed Tesla Motors before Elon Musk's involvement."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Tesla Motors",
#        "edge": "Elon Musk took an active role within Tesla Motors, overseeing Roadster product design, and became CEO in 2008."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Tesla Motors",
#        "edge": "Elon Musk was designated as a Tesla cofounder in a 2009 lawsuit settlement."
#    },
#    {
#        "node_1": "Tesla Motors",
#        "node_2": "Model S",
#        "edge": "Tesla Motors began delivery of the four-door Model S sedan in 2012."
#    },
#    {
#        "node_1": "Tesla Motors",
#        "node_2": "Model X",
#        "edge": "A crossover, the Model X, was launched by Tesla Motors in 2015."
#    },
#    {
#        "node_1": "Tesla Motors",
#        "node_2": "Model 3",
#        "edge": "A mass-market sedan, the Model 3, was released by Tesla Motors in 2017 and became the all-time bestselling plugin electric car worldwide."
#    },
#    {
#        "node_1": "Tesla Motors",
#        "node_2": "Model Y",
#        "edge": "A fifth vehicle, the Model Y crossover, was launched by Tesla Motors in 2020 and became the bestselling vehicle of any type by December 2023."
#    },
#    {
#        "node_1": "Tesla Motors",
#        "node_2": "Cybertruck",
#        "edge": "The Cybertruck, an all-electric pickup truck, was unveiled by Tesla Motors in 2019 and delivered in November 2023."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Tesla Inc.",
#        "edge": "Elon Musk is the CEO of Tesla Inc., the most valuable carmaker in summer 2020, and the sixth company in the US to reach a market capitalization of 1 trillion in October 2021."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Tesla Inc.",
#        "edge": "Elon Musk proposed selling some of his Tesla stock due to Twitter support and ended up selling a total of 164 billion dollars by year's end."
#    }
# ]
# [
#    {
#        "node_1": "Elon Musk",
#        "node_2": "SpaceX",
#        "edge": "No direct relationship found in this context."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Tesla",
#        "edge": "Elon Musk founded and was involved in various affairs of Tesla, a leading electric vehicle company."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Tesla Stock",
#        "edge": "Elon Musk's tweets led to SEC investigations and lawsuits over shareholder liability."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Securities and Exchange Commission (SEC)",
#        "edge": "Elon Musk and Tesla faced SEC investigations and fines over possible insider trading and complying with previous settlement agreements."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Kimbal Musk",
#        "edge": "Elon Musk's brother Kimbal was under investigation by the SEC alongside Elon for possible insider trading."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Optimus",
#        "edge": "Elon Musk unveiled Optimus, a robot being developed by Tesla in 2022."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Narendra Modi",
#        "edge": "Elon Musk met with Indian Prime Minister Narendra Modi in New York City in June 2023."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "India",
#        "edge": "Elon Musk expressed interest in investing in India as soon as possible after a meeting with Narendra Modi."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Tesla Energy",
#        "edge": "Tesla acquired SolarCity, a solar panel production company, and merged it with its battery unit to create Tesla Energy."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "SolarCity",
#        "edge": "Elon Musk provided the initial concept and financial capital for SolarCity, a solar panel production company."
#    },
#    {
#        "node_1": "Elon Musk",
#        "node_2": "Panasonic",
#        "edge": "Tesla and Panasonic operated a joint venture at a SolarCity factory until 2017."
#    },
#    {
#        "node_1": "Tesla",
#        "node_2": "SEC",
#        "edge": "Tesla faced multiple SEC investigations and fines over Elon Musk's tweets and alleged compliance issues."
#    },
#    {
#        "node_1": "Tesla",
#        "node_2": "Narendra Modi",
#        "edge": "Narendra Modi showed interest in Tesla's products during a meeting with Elon Musk in New York City."
#    },
#    {
#        "node_1": "Tesla",
#        "node_2": "SolarCity",
#        "edge": "Tesla acquired SolarCity for $2 billion and merged it with its battery unit to create Tesla Energy."
#    }
# ]
# [
#   {
#     "node_1": "Elon Musk",
#     "node_2": "SolarCity",
#     "edge": "Elon Musk convinced Tesla to acquire SolarCity in 2016."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Tesla",
#     "edge": "Elon Musk is the CEO of Tesla."
#   },
#   {
#     "node_1": "Tesla directors",
#     "node_2": "Elon Musk",
#     "edge": "Tesla directors initially joined Elon Musk as co-defendants in a lawsuit over SolarCity's acquisition."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Neuralink",
#     "edge": "Elon Musk co-founded Neuralink in 2016 with a $100 million investment."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Artificial Intelligence",
#     "edge": "Elon Musk aims to integrate the human brain with artificial intelligence through Neuralink."
#   },
#   {
#     "node_1": "Neuralink",
#     "node_2": "Alzheimers disease",
#     "edge": "Neuralink aims to develop a device that could treat Alzheimer's disease."
#   },
#   {
#     "node_1": "Neuralink",
#     "node_2": "Spinal cord injuries",
#     "edge": "Neuralink hopes to develop a device to treat spinal cord injuries."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Neurology",
#     "edge": "Elon Musk made claims about curing paralysis, deafness, blindness, and other disabilities with Neuralink technology."
#   },
#   {
#     "node_1": "Neuralink",
#     "node_2": "MIT Technology Review",
#     "edge": "MIT Technology Review called Neuralink's claims 'highly speculative and neuroscience theatre'."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "The Boring Company",
#     "edge": "Elon Musk founded The Boring Company in 2017 to construct tunnels in major cities."
#   },
#   {
#     "node_1": "The Boring Company",
#     "node_2": "Underground highoccupancy vehicles",
#     "edge": "The Boring Company aims to develop specialized underground highoccupancy vehicles."
#   },
#   {
#     "node_1": "University of California Davis Primate Research Center",
#     "node_2": "Neuralink",
#     "edge": "Neuralink has conducted animal trials on macaque monkeys at the University of California Davis Primate Research Center."
#   },
#   {
#     "node_1": "Elon Musk",
#     "node_2": "Food and Drug Administration",
#     "edge": "The Food and Drug Administration approved Neuralink to initiate human trials in 2023."
#   },
#   {
#     "node_1": "Neuralink",
#     "node_2": "Physicians Committee for Responsible Medicine",
#     "edge": "The Physicians Committee for Responsible Medicine has alleged that Neuralink's animal trials have violated the Animal Welfare Act."
#   }
# ]
# [
#     {
#         "node_1": "Elon Musk",
#         "node_2": "SpaceX",
#         "edge": "Elon Musk founded SpaceX."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Tesla Model X",
#         "edge": "Tesla Model Xs were used in the Los Angeles tunnel."
#     },
#     {
#         "node_1": "Elon Musk",
#         "node_2": "Twitter",
#         "edge": "Elon Musk acquired Twitter."
#     },
#     {
#         "node_1": "Elon Musk",
# ...
#         "node_2": "The Everything Store",
#         "edge": "Jeff Bezos is the subject of the book The Everything Store."
#     },
#     {
#         "node_1": "Jeff Bezos",
#         "node_2": "Donald Trump",
#         "edge": "Donald Trump went after Jeff Bezos due to cultural differences."
#     },
#     {
#         "node_1": "Jeff Bezos",
#         "node_2": "Pillsbury Biscuits",
#         "edge": "Jeff Bezos used to eat a large number of Pillsbury Biscuits daily."
#     },
#     {
#         "node_1": "Jeff Bezos",
#         "node_2": "Dwayne The Rock",
#         "edge": "Jeff Bezos was compared to Dwayne The Rock due to his physical appearance."
#     },
#     {
#         "node_1": "Jeff Bezos",
#         "node_2": "Vin Diesel",
#         "edge": "Jeff Bezos was compared to Vin Diesel due to his physical appearance."
#     },
#     {
#         "node_1": "Jeff Bezos",
#         "node_2": "Steve Carell",
#         "edge": "Steve Carell played Jeff Bezos in a Saturday Night Live sketch."
#     },
#     {
#         "node_1": "Amazon",
#         "node_2": "60 Minutes",
#         "edge": "Amazon used 60 Minutes to unveil its automated delivery drones."
#     },
#     {
#         "node_1": "Jeff Bezos",
#         "node_2": "Mens Fitness",
#         "edge": "Jeff Bezos was featured in Mens Fitness due to his physical transformation."
#     },
#     {
#         "node_1": "Tim OReilly",
#         "node_2": "Jeff Bezos",
#         "edge": "Tim OReilly wrote about Jeff Bezos and the age of Amazon."
#     },
#     {
#         "node_1": "Alan Deutschman",
#         "node_2": "Jeff Bezos",
#         "edge": "Alan Deutschman wrote an article about the mind of Jeff Bezos."
#     },
#     {
#         "node_1": "Mark OConnell",
#         "node_2": "Jeff Bezos",
#         "edge": "Mark OConnell wrote about the managerial style of Jeff Bezos."
#     },
#     {
#         "node_1": "Aine Caine",
#         "node_2": "Jeff Bezos",
#         "edge": "Aine Caine wrote about the shocking anecdotes of Jeff Bezos management style."
#     },
#     {
#         "node_1": "Gregory Bergman",
#         "node_2": "Josh Lambert",
#         "edge": "Gregory Bergman and Josh Lambert co-authored a book that features Jeff Bezos."
#     },
#     {
#         "node_1": "Brad Stone",
#         "node_2": "Jeff Bezos",
#         "edge": "Brad Stone wrote a book about Jeff Bezos and the age of Amazon."
#     }
# ]
# [
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Amazon",
#        "edge": "Jeff Bezos is the founder of Amazon, a leading tech company."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Blue Origin",
#        "edge": "Jeff Bezos founded Blue Origin to focus on space exploration."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Peter Thiel",
#        "edge": "Jeff Bezos disagreed with Peter Thiel over the Hulk Hogan vs Gawker lawsuit."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Harvard Business Review",
#        "edge": "Jeff Bezos was listed as one of the best-performing CEOs in the world by Harvard Business Review."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "International Trade Union Confederation",
#        "edge": "Jeff Bezos was voted World's Worst Boss by the International Trade Union Confederation."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "MarketWatch",
#        "edge": "Jeff Bezos was compared to a comic book supervillain in an article by MarketWatch."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Bloomberg News",
#        "edge": "Bloomberg News reported on Jeff Bezos being the world's richest person."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "New York Times",
#        "edge": "The New York Times reported on Amazon's workplace culture under Jeff Bezos' leadership."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Wired",
#        "edge": "Wired published an article about the inner life of Jeff Bezos."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Business Insider",
#        "edge": "Business Insider wrote about a day in the life of Jeff Bezos."
#    }
# ]
# [
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Business Insider",
#        "edge": "Jeff Bezos explained his famous one-character emails known to strike fear in managers' hearts in an interview with Business Insider."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Harvard Business Review",
#        "edge": "Jeff Bezos was featured in Harvard Business Review with an article titled 'The Numbers in Jeff Bezos' Head'."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Busher Center",
#        "edge": "A conversation with Jeff Bezos was held at the Busher Center in a Forum on Leadership."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Time",
#        "edge": "Jeff Bezos was named the 1999 Person of the Year by Time magazine."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Carnegie Mellon University",
#        "edge": "Jeff Bezos was a speaker at Carnegie Mellon University, specifically at the Business School and Computer Science Diploma Ceremonies."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Kindle",
#        "edge": "The creators of Kindle led by Jeff Bezos won the Innovation Award."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Fortune",
#        "edge": "Jeff Bezos was described as 'The Ultimate Disrupter' by Fortune magazine."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "BilderbergMeetings.org",
#        "edge": "Jeff Bezos was a participant in the 2011 Bilderberg Meeting."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Washington Post",
#        "edge": "Jeff Bezos was appointed chairman of the Washington-based Business Council and also owns The Washington Post."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "The World's 50 Greatest Leaders",
#        "edge": "Jeff Bezos was included in Fortune's 'The World's 50 Greatest Leaders' list in 2014."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Heinlein Prize",
#        "edge": "Jeff Bezos won the Heinlein Prize for commercial space award in 2016."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Blue Origin",
#        "edge": "Jeff Bezos founded Blue Origin."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "National Academy of Engineering",
#        "edge": "Jeff Bezos was elected as a member of the National Academy of Engineering."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Buzz Aldrin Space Innovation Award",
#        "edge": "Jeff Bezos received the first Buzz Aldrin Space Innovation Award."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Jamie Dimon",
#        "edge": "Jamie Dimon and Jeff Bezos are notable business figures mentioned in the context."
#    }
# ]
# [
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Time Magazine",
#        "edge": "Jeff Bezos was named one of the 100 most influential people by Time Magazine in 2018."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Living Legends of Aviation",
#        "edge": "Jeff Bezos was inducted into the Living Legends of Aviation, alongside other notable figures in the field."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Emmanuel Macron",
#        "edge": "Jeff Bezos was awarded the Légion d'honneur by Emmanuel Macron."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Kiddie Hawk Air",
#        "edge": "Jeff Bezos gave the keynote speech at Kiddie Hawk Air's event, showcasing his ongoing commitment to aviation."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Amazon",
#        "edge": "Jeff Bezos is the founder and CEO of Amazon, a leading e-commerce company."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "The World's Billionaire List",
#        "edge": "Jeff Bezos has consistently ranked high on the World's Billionaire List."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Forbes",
#        "edge": "Jeff Bezos has been ranked as one of the world's richest people by Forbes."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Blue Origin",
#        "edge": "Jeff Bezos founded Blue Origin to explore space."
#    }
# ]
# [
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Amazon",
#        "edge": "Jeff Bezos is the founder of Amazon."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Blue Origin",
#        "edge": "Jeff Bezos founded Blue Origin."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Bill Gates",
#        "edge": "Jeff Bezos surpassed Bill Gates as the richest person in the world."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "100 billion",
#        "edge": "Jeff Bezos became the first person to have a net worth of over 100 billion."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "2017",
#        "edge": "Jeff Bezos was named the richest person in the world in 2017."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Forbes Billionaires List",
#        "edge": "Jeff Bezos topped the Forbes Billionaires List in 2017."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "edge": "Jeff Bezos holds the record for the largest one-year net worth jump."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "112 billion",
#        "edge": "Jeff Bezos's net worth reached 112 billion in 2018."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "230000 per minute",
#        "edge": "Jeff Bezos earns approximately 230000 per minute."
#    }
# ]
# buggy JSON object 'node_2'
# [
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Amazon",
#        "edge": "Jeff Bezos is the founder of Amazon."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "MacKenzie Bezos",
#        "edge": "Jeff Bezos and MacKenzie Bezos were married for 25 years before divorcing."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "MacKenzie Bezos",
#        "edge": "As part of their divorce agreement, Jeff Bezos retained 75% of Amazon shares and voting control."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "New York City",
#        "edge": "Jeff Bezos purchased several apartments in Manhattan, totaling 17,000 square feet."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Los Angeles",
#        "edge": "Jeff Bezos bought a mansion in Los Angeles for a record $165 million."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "David Geffen",
#        "edge": "Jeff Bezos bought David Geffen's Los Angeles mansion for a record $165 million."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Tommy Mottola",
#        "edge": "Jeff Bezos was involved in a $765 million deal with Tommy Mottola."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Upper West Side",
#        "edge": "Jeff Bezos owns apartments on the Upper West Side of Manhattan."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Blue Origin",
#        "edge": "Jeff Bezos founded Blue Origin, a space exploration company."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Superyacht",
#        "edge": "Jeff Bezos owns a superyacht, which led to the dismantling of a historic bridge in Rotterdam."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "Forbes 400",
#        "edge": "Jeff Bezos is consistently ranked as one of the richest people in the world by Forbes 400."
#    },
#    {
#        "node_1": "Jeff Bezos",
#        "node_2": "$150 billion net worth",
#        "node_2_type": "net worth",
#        "edge": "Jeff Bezos' net worth surpassed $150 billion, making him the richest person in modern history."
#    }
# ]
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)

# %%
# combined_objects=[]
# for res in results:
#     try: 
#         combined_objects.extend(json.loads(res))
#     except Exception as e:
#         print('buggy JSON object', e)
# with open('30minRun.json','w') as file:
#     json.dump(combined_objects,file,indent=1)
# Out:
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
# buggy JSON object Expecting value: line 1 column 1 (char 0)
